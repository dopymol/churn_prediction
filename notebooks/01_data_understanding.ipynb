# %% [markdown]
# # Customer Churn Prediction Project
# # Notebook 1: Data Understanding
# # Goal: Load and explore the churn dataset

# %%
import pandas as pd
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('../data/churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  CUST100000    Male              0      No        Yes      61          Yes
# 1  CUST100001  Female              0      No         No      68          Yes
# 2  CUST100002    Male              0      No         No      62          Yes
# 3  CUST100003    Male              1     Yes         No       1          Yes
# 4  CUST100004    Male              0     Yes        Yes      53          Yes
#
#   InternetService        Contract     PaymentMethod  MonthlyCharges  \
# 0     Fiber optic        Two year     Bank transfer           68.29
# 1     Fiber optic        Two year  Electronic check           71.31
# 2             DSL        Two year  Electronic check           77.30
# 3             DSL  Month-to-month       Credit card           86.30
# 4             DSL  Month-to-month       Credit card           26.29
#
#    TotalCharges Churn
# 0       4208.67    No
# 1       4868.98    No
# 2       4857.57    No
# ...

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'InternetService', 'Contract',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customerID       5000 non-null   object
#  1   gender           5000 non-null   object
#  2   SeniorCitizen    5000 non-null   int64
#  3   Partner          5000 non-null   object
#  4   Dependents       5000 non-null   object
#  5   tenure           5000 non-null   int64
#  6   PhoneService     5000 non-null   object
#  7   InternetService  5000 non-null   object
#  8   Contract         5000 non-null   object
#  9   PaymentMethod    5000 non-null   object
#  10  MonthlyCharges   5000 non-null   float64
#  11  TotalCharges     4936 non-null   float64
#  12  Churn            5000 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 507.9+ KB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    5000.000000  5000.000000     5000.000000   4936.000000
# mean        0.154400    36.188400       69.709514   2564.638513
# std         0.361368    21.138531       28.725870   1918.105582
# min         0.000000     0.000000       20.040000   -262.490000
# 25%         0.000000    17.000000       45.350000   1026.402500
# 50%         0.000000    36.500000       69.295000   2102.450000
# 75%         0.000000    54.000000       94.215000   3727.122500
# max         1.000000    72.000000      119.990000   8668.040000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# InternetService     0
# Contract            0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges       64
# Churn               0
# dtype: int64
